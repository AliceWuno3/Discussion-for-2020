# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
from io import StringIO
data=pd.read_csv("vertebral_column_data/column_2C.dat", sep='\s', header=None,engine='python')
data.columns=["pelvic_incidence numeric","attribute pelvic_tilt numeric","attribute lumbar_lordosis_angle numeric"\
                           ,"sacral_slope numeric","pelvic_radius numeric","degree_spondylolisthesis numeric","class"]
data
# Out:
#      pelvic_incidence numeric  attribute pelvic_tilt numeric  \
# 0                       63.03                          22.55
# 1                       39.06                          10.06
# 2                       68.83                          22.22
# 3                       69.30                          24.65
# 4                       49.71                           9.65
# ..                        ...                            ...
# 305                     47.90                          13.62
# 306                     53.94                          20.72
# 307                     61.45                          22.69
# 308                     45.25                           8.69
# 309                     33.84                           5.07
#
#      attribute lumbar_lordosis_angle numeric  sacral_slope numeric  \
# 0                                      39.61                 40.48
# 1                                      25.02                 29.00
# ...

# %%
sns.scatterplot(data=data,x="pelvic_incidence numeric", y = "attribute pelvic_tilt numeric",hue="class")

# %%
ax=sns.boxplot( data=data,orient='h',palette="Set2")

# %%
for i in range(310):
    if data.loc[i, 'class']=='AB':
        data.loc[i, 'class']=1
    else:
        data.loc[i, 'class']=0

# %%
training_set=data[data['class']=='1'][0:140]+data[data['class']=='0'][0:70]
test_set=data[data['class']=='1'][140:]+data[data['class']=='0'][70:]
